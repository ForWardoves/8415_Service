# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sklearn.ensemble as sens
import sklearn.model_selection as ssel
import sklearn.preprocessing as spre
import sklearn.metrics as smet

# %%
data_raw = pd.read_csv('HR_Case.csv', index_col=0, true_values=['Yes'], false_values=['No'])
data_raw.head().T
# Out:
#                                         1                     2  \
# Age                                    41                    49
# Attrition                            True                 False
# BusinessTravel              Travel_Rarely     Travel_Frequently
# DailyRate                            1102                   279
# Department                          Sales  Research_Development
# DistanceFromHome                        1                     8
# Education                         College         Below_College
# EducationField              Life_Sciences         Life_Sciences
# EnvironmentSatisfaction            Medium                  High
# Gender                             Female                  Male
# HourlyRate                             94                    61
# JobInvolvement                       High                Medium
# JobLevel                                2                     2
# JobRole                   Sales_Executive    Research_Scientist
# ...

# %% [markdown]
# # Question 1
# Examine and discuss significant employee attributes that contribute to employee attrition. Elaborate on these findings to offer insights into the factors influencing employee decisions and departure from the organization.

# %%
data = data_raw.copy(deep=True)

# To identify significant employee attributes, we start by encoding all categorical values: 
label_encoders = {} # We will fit a dedicated label encoder for each column
for column in data.select_dtypes(include=['object']).columns:
    le = spre.LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

# Split target and features: 
x = data

# %%
data
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 1      41       True               2       1102           2                 1
# 2      49      False               1        279           1                 8
# 4      37       True               2       1373           1                 2
# 5      33      False               1       1392           1                 3
# 7      27      False               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 2061   36      False               1        884           1                23
# 2062   39      False               2        613           1                 6
# 2064   27      False               2        155           1                 4
# 2065   49      False               1       1023           2                 2
# 2068   34      False               2        628           1                 8
#
# ...

# %% [markdown]
# # Question 2
# Assuming that the average cost of replacing an employee is around 6 times that employee’s monthly salary, what is the cost of employee attrition for IBM given the provided dataset?

# %%
data[data.Attrition == True]
# Out:
#       Age  Attrition     BusinessTravel  DailyRate            Department  \
# 1      41       True      Travel_Rarely       1102                 Sales
# 4      37       True      Travel_Rarely       1373  Research_Development
# 19     28       True      Travel_Rarely        103  Research_Development
# 27     36       True      Travel_Rarely       1218                 Sales
# 31     34       True      Travel_Rarely        699  Research_Development
# ...   ...        ...                ...        ...                   ...
# 2023   23       True  Travel_Frequently        638                 Sales
# 2027   29       True      Travel_Rarely       1092  Research_Development
# 2032   56       True      Travel_Rarely        310  Research_Development
# 2044   50       True  Travel_Frequently        878                 Sales
# 2055   50       True      Travel_Rarely        410                 Sales
#
#       DistanceFromHome      Education    EducationField  \
# ...
